# %% [markdown]
# - https://www.mongodb.com/languages/python
# - https://medium.com/analytics-vidhya/how-to-upload-a-pandas-dataframe-to-mongodb-ffa18c0953c1

# %%
def get_database():
    from pymongo import MongoClient
    import pymongo

    # Provide the mongodb atlas url to connect python to mongodb using pymongo
    CONNECTION_STRING = "mongodb://localhost:27017"

    # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
    from pymongo import MongoClient
    client = MongoClient(CONNECTION_STRING)

    # Create the database for our example (we will use the same database throughout the tutorial
    return client['user_shopping_list']
    
# This is added so that many files can reuse the function get_database()
if __name__ == "__main__":    
    
    # Get the database
    dbname = get_database()

# %%
dbname
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'user_shopping_list')

# %%
# Imports
import pandas as pd
from pymongo import MongoClient# Load csv dataset
data = pd.read_csv('similar_movies_df.csv')# Connect to MongoDB
client =  MongoClient("mongodb://localhost:27017")
db = client['movie']
collection = db['similar_movies_1k']
data.reset_index(inplace=True)
data_dict = data.to_dict("records")# Insert collection
collection.insert_many(data_dict)

# %%
# collection

# #select the collection within the database
# test = db.test
# #convert entire collection to Pandas dataframe
# test = pd.DataFrame(list(test.find()))

# %%
df = pd.DataFrame.from_records(db.similar_movies_1k.find())
df
# Out:
#      _id  index  Unnamed: 0                                  similarity_scores
# 0      0      0           0  [(0, 0.99999976), (532, 0.70702296), (763, 0.7...
# 1      1      1           1  [(1, 0.9999998), (3, 0.80469614), (412, 0.8000...
# 2      2      2           2  [(2, 0.9999999), (853, 0.82114685), (33, 0.817...
# 3      3      3           3  [(3, 1.0000002), (1, 0.80469614), (664, 0.7755...
# 4      4      4           4  [(4, 1.0000001), (494, 0.7945222), (895, 0.791...
# ..   ...    ...         ...                                                ...
# 995  995    995         995  [(995, 0.99999994), (916, 0.770603), (117, 0.7...
# 996  996    996         996  [(996, 0.9999999), (709, 0.7512307), (635, 0.6...
# 997  997    997         997  [(997, 0.9999999), (98, 0.8098959), (871, 0.79...
# 998  998    998         998  [(998, 1.0), (873, 0.6701778), (445, 0.6624571...
# 999  999    999         999  [(999, 1.0), (118, 0.83053565), (362, 0.827098...
#
# [1000 rows x 4 columns]

# %%
### movies
data.columns.to_list()
# Out:
# ['index',
#  'Unnamed: 0',
#  'Poster_Link',
#  'Series_Title',
#  'Released_Year',
#  'Certificate',
#  'Runtime',
#  'Genre',
#  'IMDB_Rating',
#  'Overview',
#  'Meta_score',
#  'Director',
#  'Star1',
#  'Star2',
#  'Star3',
#  'Star4',
#  'No_of_Votes',
#  'Gross',
#  'title_overview',
#  'similarity_scores',
#  'similar_movies',
#  '_id']

# %%
data.tail(1)
# Out:
#      index  Unnamed: 0                                        Poster_Link  \
# 999    999         999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#      Series_Title Released_Year Certificate Runtime                     Genre  \
# 999  The 39 Steps          1935         NaN  86 min  Crime, Mystery, Thriller
#
#      IMDB_Rating                                           Overview  ...  \
# 999          7.6  A man in London tries to help a counter-espion...  ...
#
#             Star1              Star2           Star3           Star4  \
# 999  Robert Donat  Madeleine Carroll  Lucie Mannheim  Godfrey Tearle
#
#     No_of_Votes Gross                                     title_overview  \
# 999       51853   NaN  The 39 Steps A man in London tries to help a c...
#
#                                      similarity_scores  \
# 999  [(999, 1.0), (118, 0.83053565), (362, 0.827098...
#
#                                         similar_movies  _id
# ...

# %%
for x in data['Poster_Link']:
    print(x)
# Out:
# https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@.jpg
# https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@.jpg
# https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@.jpg
# https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@.jpg
# https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@.jpg
# https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@.jpg
# https://m.media-amazon.com/images/M/MV5BNGNhMDIzZTUtNTBlZi00MTRlLWFjM2ItYzViMjE3YzI5MjljXkEyXkFqcGdeQXVyNzkwMjQ5NzM@.jpg
# https://m.media-amazon.com/images/M/MV5BNDE4OTMxMTctNmRhYy00NWE2LTg3YzItYTk3M2UwOTU5Njg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@.jpg
# ...

# %%
s = 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg'
s[:s.rfind('@')+1] + '.jpg'
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@.jpg'

# %%
data['Poster_Link'] = data['Poster_Link'].apply(lambda s: s[:s.rfind('@')+1] + '.jpg')

# %%
movies_df = data[['_id',
 'Poster_Link',
 'Series_Title',
 'Released_Year',
 'Certificate',
 'Runtime',
 'Genre',
 'IMDB_Rating',
 'Overview',
 'Meta_score',
 'Director',
 'Star1',
 'Star2',
 'Star3',
 'Star4',
 'No_of_Votes',
 'Gross',
 'title_overview']]

# %%
movies_df.to_csv('movies_df.csv', index=False)

# %%
movies_df['Poster_Link'][2]
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@.jpg'

# %%
### similar_movies
similar_movies_df = data[['_id',
 'similarity_scores']]

# %%
similar_movies_df.to_csv('similar_movies_df.csv', index=False)
